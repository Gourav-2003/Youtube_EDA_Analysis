# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\HP\Documents\Youtube_EDA_Analysis\Global YouTube Statistics.csv' , encoding='latin1')

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.tail()
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 990          Sports             Natan por Aï¿     1200          Brazil
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 990           BR  Entertainment  ...                      700000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
pd.set_option("display.float_format", "{:.3f}".format)
category_subscriber_mean = df.groupby('category')['subscribers'].mean()
category_subscriber_mean
# Out:
# category
# Autos & Vehicles        17850000.000
# Comedy                  20123188.406
# Education               26542222.222
# Entertainment           21403319.502
# Film & Animation        28584782.609
# Gaming                  20852127.660
# Howto & Style           19390000.000
# Movies                  25650000.000
# Music                   25717821.782
# News & Politics         20630769.231
# Nonprofits & Activism   27750000.000
# People & Blogs          21056060.606
# Pets & Animals          18100000.000
# Science & Technology    18617647.059
# Shows                   41615384.615
# Sports                  27109090.909
# Trailers                39000000.000
# Travel & Events         12500000.000
# Name: subscribers, dtype: float64

# %%
category_subscriber_mean.sort_values(ascending = False , inplace = True )

# %%
# top 7 plot 
category_subscriber_mean.head(7).plot(kind = 'bar')
plt.title("Mean subscriber by category")
plt.xlabel("category")
plt.ylabel("subscriber")
plt.show()

# %%
# <!-- bottom 7 plot-->

category_subscriber_mean.tail(7).plot(kind = 'bar')
plt.title("Mean subscriber by category")
plt.xlabel("category")
plt.ylabel("subscriber")
plt.show()

# %%
# channel types 
channel_type_counts = df['channel_type'].value_counts()
channel_type_counts
# Out:
# channel_type
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
channel_type_counts.head(5).plot(kind = 'pie' , autopct="%1.1f%%")
plt.title("distribution of channels")
plt.show()

# %%
plt.scatter( df['subscribers'] , df['video views'] ,  marker = 'o')
plt.grid(visible  = True)

# %%
country_subscribers_counts = df.groupby('Country')['subscribers'].sum().sort_values(ascending = False)
country_subscribers_counts
# Out:
# Country
# United States           7329500000
# India                   4310600000
# Brazil                  1221800000
# United Kingdom           917400000
# Mexico                   626900000
# Indonesia                534100000
# South Korea              481700000
# Russia                   407200000
# Thailand                 386500000
# Spain                    385100000
# Canada                   363900000
# Argentina                328500000
# Colombia                 264500000
# Philippines              240100000
# Japan                    189100000
# Saudi Arabia             179100000
# Australia                172000000
# Pakistan                 155400000
# United Arab Emirates     148200000
# Ukraine                  125600000
# Germany                  116400000
# Turkey                    91600000
# Chile                     87200000
# France                    83900000
# Jordan                    67000000
# Sweden                    63000000
# ...

# %%
country_subscribers_counts.head(10).plot(kind='bar')
plt.title("Total subsriber by country")
plt.xlabel("Country")
plt.ylabel("subscribers")
plt.show()

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
pd.set_option("display.float_format", "{:.0f}".format)

df.groupby('created_year')['subscribers'].mean().sort_values(ascending = True)
# Out:
# created_year
# 2022   13640000
# 2021   18573913
# 2019   18639394
# 2017   18666176
# 2014   20618367
# 2010   20670833
# 2015   21247945
# 2020   21350000
# 2011   21800000
# 2018   23060870
# 2016   23101299
# 2009   23105769
# 2008   23652174
# 2012   24038235
# 2013   24527632
# 2007   24902041
# 2005   25829167
# 2006   31884615
# 1970   36300000
# Name: subscribers, dtype: float64

# %%
df.groupby('channel_type')['video_views_rank'].median().sort_values(ascending = False)
# Out:
# channel_type
# Autos           3468229
# Tech               2420
# Games              1944
# People             1868
# Howto              1574
# Nonprofit          1538
# Sports             1186
# Comedy             1033
# Film                880
# Entertainment       796
# News                612
# Education           538
# Music               385
# Animals             136
# Name: video_views_rank, dtype: float64

# %%
df.groupby('Country')['subscribers_for_last_30_days'].max().sort_values(ascending = False)
# Out:
# Country
# United States          8000000
# Indonesia              5500000
# United Arab Emirates   3400000
# South Korea            3200000
# Sweden                 3000000
# Turkey                 2100000
# Italy                  2000000
# India                  2000000
# Argentina              1900000
# Colombia               1600000
# Russia                 1600000
# Pakistan               1300000
# Kuwait                 1300000
# Latvia                 1200000
# Brazil                 1100000
# Japan                  1100000
# Germany                 900000
# Spain                   800000
# Australia               600000
# United Kingdom          600000
# Mexico                  600000
# Philippines             500000
# Saudi Arabia            500000
# Chile                   500000
# Canada                  400000
# Ecuador                 300000
# Thailand                300000
# Jordan                  300000
# Ukraine                 230000
# Netherlands             200000
# ...

# %%
df.groupby('created_month')['subscribers'].sum()
# Out:
# created_month
# Apr    1581200000
# Aug    1813600000
# Dec    1577300000
# Feb    1533800000
# Jan    2254600000
# Jul    1922300000
# Jun    1846400000
# Mar    2320500000
# May    1997700000
# Nov    1930200000
# Oct    1503700000
# Sep    2496200000
# Name: subscribers, dtype: int64

# %%
df.groupby('category')['video views'].std()
# Out:
# category
# Autos & Vehicles         2964425984
# Comedy                   6406251669
# Education               25572139026
# Entertainment           10128204611
# Film & Animation        10899550881
# Gaming                   5835933598
# Howto & Style            4300326961
# Movies                   3353301875
# Music                   17782784424
# News & Politics          5165961805
# Nonprofits & Activism    2698145850
# People & Blogs          12510420847
# Pets & Animals           6475165093
# Science & Technology     2937981619
# Shows                   43723894662
# Sports                  21703831459
# Trailers                 1382496086
# Travel & Events                 NaN
# Name: video views, dtype: float64

# %%
df.groupby('Country')['Unemployment rate'].min()
# Out:
# Country
# Afghanistan             11
# Andorra                NaN
# Argentina               10
# Australia                5
# Bangladesh               4
# Barbados                10
# Brazil                  12
# Canada                   6
# Chile                    7
# China                    4
# Colombia                10
# Cuba                     2
# Ecuador                  4
# Egypt                   11
# El Salvador              4
# Finland                  7
# France                   8
# Germany                  3
# India                    5
# Indonesia                5
# Iraq                    13
# Italy                   10
# Japan                    2
# Jordan                  15
# Kuwait                   2
# Latvia                   7
# Malaysia                 3
# Mexico                   3
# Morocco                  9
# Netherlands              3
# Pakistan                 4
# Peru                     3
# Philippines              2
# Russia                   5
# ...

# %%
df.groupby(['channel_type'])['uploads'].sum().sort_values(ascending = False)
# Out:
# channel_type
# News             3989151
# Entertainment    3345035
# Music             424950
# Games             399473
# Nonprofit         205824
# Sports            158995
# Education         146355
# People            117424
# Film              114654
# Comedy             81722
# Howto              79417
# Animals            42868
# Tech               33780
# Autos                949
# Name: uploads, dtype: int64

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# df['Country', 'Latitude', 'Longitude']
df[['Country', 'Latitude', 'Longitude']].head(40)
# Out:
#            Country  Latitude  Longitude
# 0            India        21         79
# 1    United States        37        -96
# 2    United States        37        -96
# 3    United States        37        -96
# 4            India        21         79
# 5              NaN       NaN        NaN
# 6    United States        37        -96
# 7            Japan        36        138
# 8           Russia        62        105
# 9    United States        37        -96
# 10           India        21         79
# 11   United States        37        -96
# 12             NaN       NaN        NaN
# 13     South Korea        36        128
# 14             NaN       NaN        NaN
# 15           India        21         79
# 16  United Kingdom        55         -3
# 17     South Korea        36        128
# 18   United States        37        -96
# 19          Canada        56       -106
# 20     South Korea        36        128
# 21           India        21         79
# ...

# %%
sns.boxenplot(data = df , x='channel_type' , y='highest_monthly_earnings' , palette='Set1')
plt.title("Distribution of highest_monthly_earnings by channel_type")
plt.xticks(rotation = 45)
plt.xlabel("channel_type")
plt.ylabel("highest_monthly_earnings")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7320\757235720.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(data = df , x='channel_type' , y='highest_monthly_earnings' , palette='Set1')

# %%
df.groupby(['category' , 'Country'])['subscribers'].sum().unstack().plot(kind='bar' , stacked = True)
plt.title("Subscribers Breakdown By Country and Categort")
plt.xlabel('Category')
plt.ylabel("Total subscribers")
plt.xticks(rotation = 90)
plt.legend(title = "Country", bbox_to_anchor = (1.05 ,1)  , loc='upper left')
plt.show()

# %%
sns.scatterplot(data = df , x = 'Gross tertiary education enrollment (%)' , y='subscribers'  , palette = 'Set1')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7320\3011188396.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data = df , x = 'Gross tertiary education enrollment (%)' , y='subscribers'  , palette = 'Set1')

# %%
df.groupby('channel_type')['Unemployment rate'].mean().plot(kind = "bar")
plt.title("Avg unemployment rate By channel type")
plt.xlabel("channel type")
plt.ylabel("Unemployment rate")
plt.show()

# %%
pd.set_option("display.float_format", "{:.0f}".format)


df.groupby(['created_year' ,'channel_type'])['subscribers'].mean().unstack().tail().plot(kind='bar' , width = 1)
plt.title("Avg subscribers By channel type and created year")
plt.xlabel("Created Year")
plt.ylabel("Average subscriber") 
plt.xticks(rotation = 45)
plt.legend(title="Channel Type" , bbox_to_anchor = (1.5 , 1) , loc = "upper right")
plt.show()

# %%
pd.set_option("display.float_format", "{:.0f}".format)

df.groupby(['created_year' , 'created_month'])['subscribers'].sum().unstack().head().plot(kind = 'bar' , stacked = True)
plt.title("Total subscriber By created month and created year")
plt.xlabel("Created month")
plt.legend(title = "Created Year" , bbox_to_anchor = (1.3 , 1) , loc = "upper right")
plt.ylabel("Total subscribers")
plt.show()

# %%
df.groupby(['created_year' , 'created_month'])['subscribers'].sum().unstack().head().plot(kind = 'area' , stacked = True)
plt.title("Total subscriber By created month and created year")
plt.xlabel("Created Year")
plt.legend(title = "Created Month" , bbox_to_anchor = (1.3 , 1) , loc = "upper right")
plt.ylabel("Total subscribers")
plt.show()

# %%
df.groupby(['created_year' , 'Country'])['highest_yearly_earnings'].mean().unstack().head().plot(kind='line' , marker='o')
plt.title("Trend of Highest Yearly Earnings by Created Year and Country")
plt.xlabel("Created year")
plt.ylabel("Average Highest Yearly Earnings")
plt.legend(title = "Country", bbox_to_anchor = (1.05,1), loc = 'upper left')
plt.show()

# %%
category_monthly_highest_earnings_sum = df.groupby('category')['highest_monthly_earnings'].sum().sort_values(ascending = False).head()

# %%
category_monthly_highest_earnings_sum.plot(kind = 'pie' , autopct = "%1.1f%%")
plt.title("Category Highest Monthly Earnings")
plt.ylabel('')
plt.show()
